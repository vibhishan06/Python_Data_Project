# %% [markdown]
# **SETS**
#
#
# ---
# For Unique Items (removes duplicate items in the output)
#
# ---
# **Syntax:** {item1, item2, ...}

# %%
job_skills = {"tableau", "sql", "python", "statistics"}

# %%
job_skills
# Out:
# {'python', 'sql', 'statistics', 'tableau'}

# %%
job_skills.add("looker")

# %%
job_skills
# Out:
# {'looker', 'python', 'sql', 'statistics', 'tableau'}

# %%
job_skills.add("sql")

# %%
job_skills
# Out:
# {'looker', 'python', 'sql', 'statistics', 'tableau'}

# %%
job_skills.pop()
# Out:
# 'python'

# %%
job_skills
# Out:
# {'looker', 'sql', 'statistics', 'tableau'}

# %%
job_skills.remove("tableau")

# %%
job_skills
# Out:
# {'looker', 'sql', 'statistics'}

# %%
job_skills.add("python")

# %%
job_skills
# Out:
# {'looker', 'python', 'sql', 'statistics'}

# %%
job_skills.remove("statistics")

# %%
job_skills
# Out:
# {'looker', 'python', 'sql'}

# %%
skill_list = ["python", "sql", "statistics", "tableau", "python", "sql", "statistics", "tableau"]

# %%
set(skill_list)                     # to remove duplicate values
# Out:
# {'python', 'sql', 'statistics', 'tableau'}

# %%
list(set(skill_list))
# Out:
# ['tableau', 'statistics', 'python', 'sql']
