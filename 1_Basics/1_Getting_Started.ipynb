# %% [markdown]
# Python Basics

# %%
2 + 2
# Out:
# 4

# %%
2 + 2
3 * 3
# Out:
# 9

# %%
print(2 + 2)
print(3 * 3)
# Out:
# 4
# 9

# %%
print(2 + 2)
3 * 3
# Out:
# 4
# 9

# %% [markdown]
# Make a Comment

# %%
# This is a comment in Python. Comments start with [#] sign

# %%
# This is a comment
2 + 2 #This adds 2 and 2
# Out:
# 4

# %% [markdown]
# **Advanced Jupyter Notebook Usage**

# %%
# !ls # !| Shell Command |
# Out:
# sample_data

# %%
# %timeit [i**2 for i in range(1000)]       # Line Magic
# Out:
# 79.6 µs ± 31.8 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %%timeit
L = []
for n in range(1000):
  L.append(n**2)
# Out:
# 90.6 µs ± 26 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %% [markdown]
# **VARIABLES**

# %% [markdown]
# Create a variable

# %%
# variable_name = variable_value

# %%
salary = 100000

# %%
salary
# Out:
# 100000

# %%
"salary"
# Out:
# 'salary'

# %% [markdown]
# ** Calculate the following**

# %% [markdown]
# Total Salary = (Base Salary)*(1 + Bonus Rate)

# %%
base_salary = 100000
bonus_rate = 0.10

# %%
total_salary = (base_salary) * (1 + bonus_rate)

# %%
total_salary
# Out:
# 110000.00000000001

# %% [markdown]
# **Variables are'nt only numbers**

# %% [markdown]
# Example
#
# ---
# Create variables to store the following information about a job posting
#
#
# *   Job ID (integer)
# *   Company Name (string)
# *   Salary Rate (strings but consider how you might store this as a numerical type for calculation)
# *   Job Work From Home (boolean)

# %%
company_name = 'DataWiz Inc.'

# %%
company_name
# Out:
# 'DataWiz Inc.'

# %%
job_wfh = True

# %%
job_wfh
# Out:
# True

# %%
job_id = 101
job_title = "Data Analyst"
job_salary = 125000

# %%
print("Data Job Description")
print("+++++++++++++++++++++")
print("Job ID:    ", job_id)
print("Company Name:", company_name)
print("Job Title:   ", job_title)
print("Salary:      ", job_salary)
print("Work From Home:", job_wfh)
# Out:
# Data Job Description
# +++++++++++++++++++++
# Job ID:     101
# Company Name: DataWiz Inc.
# Job Title:    Data Analyst
# Salary:       125000
# Work From Home: True
