# %% [markdown]
# **ARITHMETIC OPERATORS**

# %%
2 + 3.0
# Out:
# 5.0

# %%
"What's " + "Up" + "!"
# Out:
# "What's Up!"

# %%
"What's up? " * 10
# Out:
# "What's up? What's up? What's up? What's up? What's up? What's up? What's up? What's up? What's up? What's up? "

# %%
3.0 - 2
# Out:
# 1.0

# %%
four = 4

four.__sub__(2)
# Out:
# 2

# %%
4 - 2
# Out:
# 2

# %%
5 / 2
# Out:
# 2.5

# %%
5 // 2 #floor division
# Out:
# 2

# %%
5 % 2 #Modulus - prints the remainder
# Out:
# 1

# %% [markdown]
# **ORDER OF OPERATIONS**
#
#
# ---
# 1. **Parentheses:** Anything in parentheses is executed first.
# 2. **Exponents:** Operations involving exponents(including roots, indicated as fractional exponents).
# 3. **Multiplication and Division:** Processed from left to right.
# 4. **Addition and Subtraction:** Also processed from left to right.

# %%
min_salary = 20_000   # _ is ignored by the interpreter
max_salary = 80_000

avg_salary = (min_salary + max_salary) / 2

avg_salary
# Out:
# 50000.0

# %% [markdown]
# Assignment Operators

# %%
applicant_1 = "Kelly"
applicant_2 = "Luke"

# %%
temp_var = applicant_1

# %%
applicant_1 = applicant_2
applicant_2 = temp_var

# %%
applicant_1, applicant_2
# Out:
# ('Luke', 'Kelly')

# %% [markdown]
# or

# %%
applicant_1 = "Kelly"
applicant_2 = "Luke"

# %%
applicant_1, applicant_2 = applicant_2, applicant_1

# %%
applicant_1, applicant_2
# Out:
# ('Luke', 'Kelly')

# %%
x = 1

# %%
x = x + 1

# %%
x
# Out:
# 2

# %% [markdown]
# or

# %%
x = 1

x += 1    # x = x + 1

# %%
x
# Out:
# 2

# %%
x = 1

# %%
x *= 2

# %%
x
# Out:
# 2

# %% [markdown]
# Comparison Operators

# %%
salary_kelly = 60_000
salary_luke = 40_000

# %%
salary_kelly == salary_luke
# Out:
# False

# %%
if (salary_kelly > salary_luke):
  print("Kelly is paid more than Luke")
elif (salary_kelly < salary_luke):
  print("Luke is paid more than Kelly")
else:
  print("Kelly and Luke make the same amount")
# Out:
# Kelly is paid more than Luke
